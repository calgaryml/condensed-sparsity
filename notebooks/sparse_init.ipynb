# %%
import torch

from typing import Optional
import logging
from rigl_torch.utils.rigl_utils import *

# %%
conv1 = torch.nn.Conv2d(
    in_channels=3,
    out_channels=32,
    kernel_size=(3,3),
    stride=1,
    padding="same"
)

# %%
conv1.weight.min()
# Out:
# tensor(-0.1912, grad_fn=<MinBackward1>)

# %%
conv1.weight.mean()
# Out:
# tensor(0.0031, grad_fn=<MeanBackward0>)

# %%
import math
k = 1 / ( conv1.in_channels * math.prod(conv1.kernel_size) ) 
math.sqrt(k)
# Out:
# 0.19245008972987526

# %%
mask = torch.ones(size=conv1.weight.shape)
start_of_zeros = mask.numel() //2 
mask = mask.view(-1)
mask[start_of_zeros:] = 0 
idx = torch.randperm(mask.shape[0])
mask= mask[idx].reshape(conv1.weight.shape)

# %%
with torch.no_grad():
    conv1.weight *= mask

# %%
active_weights_per_neuron = [neuron.sum().item() for neuron in mask]

active_weights_per_neuron
# Out:
# [15.0,
#  18.0,
#  16.0,
#  17.0,
#  10.0,
#  10.0,
#  19.0,
#  10.0,
#  12.0,
#  11.0,
#  9.0,
#  15.0,
#  15.0,
#  13.0,
#  13.0,
#  16.0,
#  14.0,
#  9.0,
#  12.0,
#  12.0,
#  14.0,
#  13.0,
#  16.0,
#  17.0,
#  13.0,
#  14.0,
#  10.0,
#  11.0,
#  14.0,
#  16.0,
#  13.0,
#  15.0]

# %%
fan_in_tensor = get_fan_in_tensor(mask)
fan_in_tensor
# Out:
# tensor([15, 18, 16, 17, 10, 10, 19, 10, 12, 11,  9, 15, 15, 13, 13, 16, 14,  9,
#         12, 12, 14, 13, 16, 17, 13, 14, 10, 11, 14, 16, 13, 15])

# %%
with torch.no_grad():
    conv1.weight[1].normal_(0,1)

# %%
gain = math.sqrt(2.0)
updated_tensor = conv1.weight.clone()
for i in range(len(mask)):
    fan_in = fan_in_tensor[i]
    std = gain / math.sqrt(fan_in)
    if i == 0:
        neuron_at_zero = updated_tensor[0]
    with torch.no_grad():
        updated_tensor[i] = updated_tensor[i].normal_(0,std)
    if i != 0:
        assert (neuron_at_zero == updated_tensor[0]).all()
        
updated_tensor *= mask

# %%
conv1.weight[mask]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 conv1.weight[mask]
#
# IndexError: tensors used as indices must be long, byte or bool tensors

# %%
type(mask)
# Out:
# torch.Tensor

# %%
mask = mask.to(torch.bool)

# %%
conv1.weight.masked_select(mask)
# Out:
# tensor([ 1.7190e-01, -4.7952e-02, -3.7306e-02, -1.1591e-02,  8.6550e-02,
#         -1.5842e-01, -1.4070e-01,  2.6583e-02, -8.3651e-02, -3.8811e-02,
#         -8.3743e-02, -1.0348e-01,  1.8720e-02,  1.0755e-02,  1.9022e-01,
#         -7.7309e-02, -7.6543e-02,  1.1409e-01,  5.0463e-02, -4.4772e-02,
#         -1.5374e-02, -1.7493e-02, -6.9071e-02, -1.8608e-01,  1.2023e-02,
#         -1.5188e-01,  5.3804e-02,  1.6484e-02, -1.0767e-01, -8.7878e-02,
#         -4.9170e-02,  1.0453e-01,  1.8108e-01,  4.0512e-02, -3.4362e-02,
#         -4.7837e-02, -3.3729e-02, -1.8923e-01,  1.2815e-01,  9.9988e-02,
#          3.9296e-02,  9.0425e-02,  8.5881e-02, -1.7568e-01, -2.7048e-03,
#         -1.2987e-01,  5.7887e-02,  2.8742e-02, -3.2435e-02,  1.2271e-01,
#          1.0330e-01, -1.5976e-01, -4.9739e-02,  1.6230e-01,  3.9779e-03,
#          1.8952e-02, -3.2602e-02,  1.7024e-01, -8.7411e-02, -1.1226e-01,
#         -1.3192e-01, -9.6221e-02,  1.4342e-01,  1.0929e-01, -9.7288e-02,
#          3.8373e-02, -1.2387e-01, -7.2410e-02, -1.4156e-01,  1.7562e-01,
#         -8.3268e-02, -1.0078e-01, -1.8647e-01,  1.9189e-01, -5.9968e-02,
#          1.4328e-01, -3.8034e-02, -5.4251e-03, -6.1488e-02, -1.8200e-01,
#          7.5034e-02,  1.7741e-01, -1.3940e-01,  1.0281e-01, -1.9169e-01,
#          8.9534e-02,  6.0686e-02, -1.5781e-01,  2.8625e-02,  1.2200e-01,
#         -2.5091e-02, -1.6387e-01, -1.7555e-01, -1.8029e-02,  8.1653e-03,
#          1.5234e-02, -1.5207e-01], grad_fn=<MaskedSelectBackward0>)

# %%
torch.where(
    mask,
    
)

# %%
conv1.weight[0]
# Out:
# tensor([[[ 0.0000,  0.1719, -0.0000],
#          [-0.0480, -0.0000,  0.0000],
#          [-0.0000, -0.0373, -0.0000]],
#
#         [[-0.0116, -0.0000, -0.0000],
#          [ 0.0865, -0.1584, -0.1407],
#          [ 0.0266, -0.0837, -0.0388]],
#
#         [[-0.0837,  0.0000, -0.1035],
#          [ 0.0187,  0.0000, -0.0000],
#          [ 0.0108, -0.0000,  0.1902]]], grad_fn=<SelectBackward0>)

# %%
updated_tensor[0]
# Out:
# tensor([[[-0.0000, -0.1293,  0.0000],
#          [-0.3681,  0.0000, -0.0000],
#          [ 0.0000,  0.0626,  0.0000]],
#
#         [[ 0.3123,  0.0000,  0.0000],
#          [-0.5981,  0.0905, -0.2842],
#          [ 0.2263,  0.4572,  0.0855]],
#
#         [[ 0.4777, -0.0000,  0.3340],
#          [ 0.6535, -0.0000,  0.0000],
#          [ 0.2555, -0.0000,  0.3668]]], grad_fn=<SelectBackward0>)

# %%
conv1.weight.max(), conv1.weight.min()
# Out:
# (tensor(0.1921, grad_fn=<MaxBackward1>),
#  tensor(-0.1923, grad_fn=<MinBackward1>))

# %%
conv1.weight[0].max(), conv1.weight[0].min()
# Out:
# (tensor(0.1888, grad_fn=<MaxBackward1>),
#  tensor(-0.1706, grad_fn=<MinBackward1>))

# %%
updated_tensor[0].max(), updated_tensor[0].min()
# Out:
# (tensor(0.4831, grad_fn=<MaxBackward1>),
#  tensor(-0.6985, grad_fn=<MinBackward1>))

# %%
gain / math.sqrt(fan_in_tensor[0])
# Out:
# 0.37796447300922725

# %%
updated_tensor[0] = 0

# %%
updated_tensor *= mask

# %%
updated_tensor
# Out:
# tensor([[[[ 0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000]],
#
#          [[ 0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000]],
#
#          [[ 0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000]]],
#
#
#         [[[ 0.0000,  0.1637,  0.6784],
#           [ 0.0000,  0.0000,  0.0000],
#           [-0.0000, -0.0000,  0.0000]],
#
#          [[-0.2891, -0.5376,  0.0000],
#           [-0.0258,  0.5696,  0.0085],
#           [-0.2021,  0.2465, -0.0000]],
#
#          [[ 0.0604,  0.3006, -0.0000],
#           [-0.0381,  0.0000,  0.0000],
#           [ 0.0000, -0.0000, -0.3074]]],
#
#
#         [[[-0.3855, -0.0000, -0.3334],
#           [ 0.0000,  0.4683, -0.3986],
#           [-0.0000,  0.2333,  0.0473]],
#
#          [[-0.2454,  0.2809,  0.0000],
#           [ 0.4172, -0.0000,  0.0092],
#           [-1.0648,  0.0000,  0.0000]],
#
#          [[-0.0492,  0.4232, -0.1303],
#           [-0.0000, -0.0609, -0.2260],
#           [ 0.0000,  0.0000,  0.0000]]],
#
#
#         [[[-0.0000,  0.0000, -0.2087],
#           [ 0.0000,  0.1220,  0.4660],
#           [-0.1791, -0.1456,  0.0000]],
#
#          [[-0.1922,  0.6189, -0.0000],
#           [-0.0000,  0.0000,  0.8064],
#           [ 0.0000, -0.3371,  0.0000]],
#
#          [[ 0.0000,  0.0000, -0.3570],
#           [ 0.2760, -0.1919, -0.0000],
#           [-0.0000, -0.0000,  0.0000]]],
#
#
#         [[[-0.0779,  0.0000, -0.3607],
#           [-0.0000, -0.0000,  0.4150],
#           [ 0.0000, -0.0000,  0.0399]],
#
#          [[-0.0000, -0.0000, -0.1128],
#           [-0.0422, -0.1847, -0.0000],
#           [ 0.2712, -0.4149, -0.2535]],
#
#          [[-0.0000, -0.6179, -0.0000],
#           [ 0.2679, -0.0000,  0.4012],
#           [ 0.0000, -0.0000, -0.0000]]],
#
#
#         [[[ 0.0560, -0.0000, -0.0000],
#           [-0.0000,  0.0543,  0.0000],
#           [ 0.0000, -0.0000,  0.6684]],
#
#          [[-0.0000, -0.1715,  0.0000],
#           [-0.0000,  0.0000,  0.0000],
#           [-0.3172, -0.0000, -0.0212]],
#
#          [[-0.3457, -0.0777,  0.2030],
#           [-0.5367,  0.1874,  0.0000],
#           [-0.6530, -0.0000, -0.1156]]],
#
#
#         [[[-0.0000, -0.0000,  0.0000],
#           [-0.6967, -0.0585,  0.0000],
#           [ 0.0000, -0.0714, -0.0000]],
#
#          [[-0.0000,  0.3376,  0.0000],
#           [ 0.3306,  0.0000,  0.0000],
#           [ 0.0000,  0.0000, -0.2161]],
#
#          [[-0.5657, -0.3127,  0.6900],
#           [ 0.0000,  0.2264, -0.2058],
#           [-0.0000,  0.4481,  0.3355]]],
#
#
#         [[[-0.0850, -0.0000, -0.0000],
#           [-0.0959, -0.0000, -0.0000],
#           [ 0.1263, -0.6432,  0.0944]],
#
#          [[-0.0000,  0.1866, -0.6139],
#           [-0.0000, -0.0000, -0.1479],
#           [-0.0000, -0.0000, -0.1615]],
#
#          [[ 0.0829,  0.0000,  0.0462],
#           [-0.2590,  0.1465, -0.3257],
#           [ 0.0000,  0.0000, -0.0000]]],
#
#
#         [[[-0.2874,  0.6909,  0.0000],
#           [ 0.0000,  0.1185,  0.0000],
#           [-0.0000,  0.3286,  0.2455]],
#
#          [[ 0.0402,  0.0999,  0.0000],
#           [-0.0000, -0.3400, -0.0000],
#           [-0.1503,  0.0000,  0.2302]],
#
#          [[-0.0000,  0.0000, -0.0000],
#           [-0.0000,  0.0000, -0.0000],
#           [ 0.1544, -0.3750, -0.0000]]],
#
#
#         [[[ 0.3731,  0.1978,  0.0000],
#           [-0.4470, -0.5530,  0.6206],
#           [ 0.0000,  0.0000, -0.2336]],
#
#          [[ 0.3906, -0.0000,  0.0000],
#           [ 0.5116,  0.1743,  0.0000],
#           [ 0.0000,  0.0000,  0.4242]],
#
#          [[ 0.0000, -0.0000, -0.7384],
#           [ 0.0000,  0.3422,  0.0000],
#           [-0.2455,  0.3032, -0.6820]]],
#
#
#         [[[-0.1333,  0.0000, -0.6579],
#           [-0.0292,  0.8817,  0.0000],
#           [ 0.1418, -0.3907, -0.2760]],
#
#          [[-0.2951,  0.4245, -0.0000],
#           [-0.0000,  0.1207,  0.0000],
#           [-0.0277,  0.1528,  0.1460]],
#
#          [[-0.0000,  0.2774,  0.4820],
#           [ 0.0000, -0.0248,  0.5720],
#           [ 0.3853, -0.0000,  0.1114]]],
#
#
#         [[[ 0.7855, -0.4388, -0.1474],
#           [-0.1151, -0.0000, -0.5860],
#           [ 0.3442,  0.2488,  0.0000]],
#
#          [[ 0.2053,  0.5887,  0.0000],
#           [-0.0000, -0.0000, -0.2121],
#           [ 0.1075,  0.0000,  0.1527]],
#
#          [[ 0.0000,  0.1896, -0.0000],
#           [-0.0000,  0.0470,  0.5089],
#           [ 0.1450, -0.8440,  0.0000]]],
#
#
#         [[[-0.2212, -0.0000,  0.0000],
#           [ 0.0000, -0.0000,  0.0000],
#           [-0.0000, -0.0071,  0.1453]],
#
#          [[-0.1525,  0.3191,  0.0040],
#           [ 0.3394,  0.0000, -0.0000],
#           [-0.2965,  0.0000,  0.0000]],
#
#          [[-0.0791, -0.4968,  0.0000],
#           [ 0.0000, -0.0000,  0.1377],
#           [-0.0000,  0.0000,  0.0242]]],
#
#
#         [[[-0.0000,  0.1613,  0.2766],
#           [-0.0000,  0.0000,  0.3142],
#           [-0.0000,  0.0000,  0.0409]],
#
#          [[ 0.0558, -0.0727, -0.2552],
#           [-0.5051, -0.0000,  0.0339],
#           [ 0.2884, -0.3538,  0.1297]],
#
#          [[-0.3282,  0.1006,  0.4231],
#           [-0.2751, -0.0617,  0.0000],
#           [-0.2895,  0.0000, -0.0000]]],
#
#
#         [[[-0.3547,  0.0517,  0.0704],
#           [ 0.1573, -0.0000,  0.0000],
#           [ 0.0000, -0.0000, -0.0000]],
#
#          [[-0.2123,  0.1896,  0.6897],
#           [ 0.0000, -0.2359, -0.2019],
#           [ 0.0000, -0.0000,  0.0000]],
#
#          [[-0.2036, -0.0000,  0.4546],
#           [-0.4416, -0.0000, -0.0653],
#           [-0.0000, -0.0042, -0.0000]]],
#
#
#         [[[ 0.0000,  0.7770,  0.0000],
#           [ 0.0000,  0.0000, -0.0000],
#           [-0.0000,  0.5323, -0.0000]],
#
#          [[-0.0000, -0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000],
#           [-0.0000,  0.0000, -1.0413]],
#
#          [[ 0.0000,  0.6729,  0.8413],
#           [-0.0000,  0.0000,  0.5136],
#           [ 0.0000, -0.5009,  0.5778]]],
#
#
#         [[[ 0.0218, -0.1136,  0.6730],
#           [ 0.3654,  0.1452, -0.0000],
#           [ 0.0140,  0.2985, -0.0000]],
#
#          [[ 0.0000,  0.0000, -0.0000],
#           [-0.0000, -0.0000, -0.0000],
#           [-0.0000, -0.2041,  0.1810]],
#
#          [[-0.0000, -0.5763,  0.4479],
#           [ 0.1076, -0.0000, -0.3805],
#           [ 0.1860,  0.0000, -0.4389]]],
#
#
#         [[[-0.0000,  0.0000, -0.1728],
#           [-0.0000, -0.0000,  0.0000],
#           [ 0.0000,  0.1744,  0.0000]],
#
#          [[ 0.2934,  0.0000,  0.0000],
#           [ 0.2198,  0.6265,  1.0186],
#           [-0.6731, -0.0000, -0.3005]],
#
#          [[-0.0000,  0.0000, -0.1957],
#           [-0.0000, -0.0000,  0.0000],
#           [ 0.0000,  0.5527,  0.0000]]],
#
#
#         [[[-0.4651, -0.1081, -0.8477],
#           [ 0.5847,  0.0000, -0.0000],
#           [-0.0000,  0.0000,  0.0000]],
#
#          [[ 0.0000, -0.0000,  0.0911],
#           [ 0.0000,  0.0000,  0.0000],
#           [ 0.3918, -0.0000, -0.3036]],
#
#          [[ 0.1751,  0.0981,  0.0000],
#           [ 0.0000, -0.6031, -0.0000],
#           [-0.8901, -0.0000, -0.0116]]],
#
#
#         [[[-0.2041, -0.0000,  0.2023],
#           [-0.0000,  0.0000,  0.5421],
#           [ 0.5222,  0.4091, -0.0000]],
#
#          [[-1.0979, -0.0000, -0.0000],
#           [ 0.0000, -0.0000, -0.0000],
#           [ 0.0000,  0.1271,  0.0000]],
#
#          [[-0.3465, -0.2806, -0.1198],
#           [-0.2705, -0.4365,  0.0000],
#           [-0.0000, -0.0000,  0.0000]]],
#
#
#         [[[-0.0000,  0.1791, -0.2982],
#           [ 0.0000,  0.0000, -0.3959],
#           [ 0.0853, -0.5681, -0.0000]],
#
#          [[ 0.4559,  0.1208,  0.0000],
#           [-0.0000,  0.0000,  0.0000],
#           [-0.0593,  0.1004,  0.2152]],
#
#          [[-0.0933, -0.4359, -0.0000],
#           [-0.0000, -0.0000, -0.5467],
#           [ 0.0252,  0.8169, -0.2932]]],
#
#
#         [[[ 0.0000, -0.5685,  0.0000],
#           [-0.7352, -0.0000,  0.1457],
#           [ 0.0938,  0.2992,  0.2528]],
#
#          [[ 0.2265, -0.0000,  0.0000],
#           [ 0.6410,  0.1435,  0.0000],
#           [ 0.0000,  0.3099, -0.0000]],
#
#          [[-0.0000,  0.4044,  0.1066],
#           [ 0.0114, -0.1011,  0.0840],
#           [ 0.0000, -0.1587, -0.0000]]],
#
#
#         [[[-0.0922, -0.0000,  0.1458],
#           [-0.0138,  0.0000,  0.5935],
#           [-0.0746, -0.0000,  0.1212]],
#
#          [[ 0.0653, -0.0441,  0.0927],
#           [ 0.0000,  0.0384, -0.0000],
#           [ 0.0000,  0.0279, -0.2503]],
#
#          [[ 0.0000,  0.1963, -0.5153],
#           [-0.0000,  0.0000,  0.0000],
#           [-0.0000,  0.0000, -0.0000]]],
#
#
#         [[[-0.3501, -0.4810,  0.0000],
#           [ 0.0219, -0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.7121]],
#
#          [[ 0.0467, -0.0000, -0.1344],
#           [-0.0000,  0.0000, -0.0000],
#           [-0.4577,  0.0000, -0.2507]],
#
#          [[ 0.0292,  0.5860, -0.0000],
#           [ 0.0939,  0.3817,  0.3168],
#           [-0.0000, -0.0000,  0.0000]]],
#
#
#         [[[ 0.9954, -0.0000,  0.0000],
#           [-0.1400,  0.0000, -0.0000],
#           [-0.0000,  0.0000, -0.2781]],
#
#          [[ 0.1084, -0.2865, -0.0000],
#           [-0.0000,  0.0000, -0.3339],
#           [-0.2930, -0.1142, -0.0000]],
#
#          [[ 0.3995,  0.0000,  0.5374],
#           [ 0.0987, -0.0000,  0.0000],
#           [-0.0062,  0.0000, -0.0338]]],
#
#
#         [[[ 0.5973,  0.0000,  0.0000],
#           [-0.8326, -0.0000, -0.0000],
#           [ 0.3752, -0.6558,  0.0000]],
#
#          [[ 0.0000,  0.0000, -0.0000],
#           [ 0.0000, -0.0000, -0.0000],
#           [-0.0000, -0.0000, -0.1509]],
#
#          [[ 0.0000,  0.0000, -0.5745],
#           [-0.2659, -0.0000,  0.2804],
#           [ 0.1602,  0.1078, -0.3234]]],
#
#
#         [[[ 0.0609,  0.0000,  1.1040],
#           [-0.1891, -0.0000,  0.0000],
#           [-0.2654,  0.1497,  0.5503]],
#
#          [[-0.0000, -0.0000, -0.0000],
#           [ 0.0000, -0.0000, -0.0000],
#           [-0.2579, -0.0000, -0.5437]],
#
#          [[-0.2253, -0.0000, -0.2761],
#           [ 0.0000, -0.2366,  0.3073],
#           [ 0.0000, -0.0285, -0.0000]]],
#
#
#         [[[-0.0000,  0.0000, -0.0000],
#           [-0.0852,  0.6238, -0.0000],
#           [-0.0000, -0.0000,  0.2005]],
#
#          [[-0.0000, -0.0853,  0.5432],
#           [-0.1012, -0.3704, -0.1527],
#           [ 0.0423, -0.0000, -0.0018]],
#
#          [[-0.0000,  0.3231, -0.2942],
#           [ 0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.4949, -0.0000]]],
#
#
#         [[[-0.6765, -0.0000, -0.5199],
#           [-0.0022,  0.0515, -0.0000],
#           [-0.2293,  0.0722, -0.0000]],
#
#          [[ 0.0000, -0.3862,  0.0000],
#           [-0.0371,  0.0000, -0.0836],
#           [ 0.2004, -0.6084, -0.0000]],
#
#          [[ 0.0000, -0.2051, -0.0000],
#           [-0.1798, -0.0000,  0.0000],
#           [-0.0651, -0.4482, -0.4264]]],
#
#
#         [[[ 0.0000, -0.0000,  0.0000],
#           [ 0.0000, -0.4541,  0.1030],
#           [ 0.0000,  0.0000, -0.0000]],
#
#          [[ 0.0000, -0.2180,  0.0000],
#           [ 0.0000, -0.2228, -0.6142],
#           [ 0.0000, -0.0000, -0.6423]],
#
#          [[-0.2354, -0.1241,  0.1937],
#           [ 0.8604,  0.0000, -0.0000],
#           [-0.4269, -0.1610, -0.2677]]],
#
#
#         [[[ 0.0000,  0.5419, -0.0000],
#           [-0.0000,  0.0000, -0.1129],
#           [-0.2761,  0.0000, -0.3127]],
#
#          [[ 0.1952, -0.0000, -0.0000],
#           [ 0.0000,  0.0000,  0.1198],
#           [-0.2166, -0.0000, -0.0000]],
#
#          [[ 0.0000, -0.5526,  0.0000],
#           [-0.0000, -0.0000,  0.0000],
#           [-0.4053, -0.2405, -0.5887]]],
#
#
#         [[[ 0.0000,  0.0000, -0.0000],
#           [ 0.2271,  0.4663,  0.0000],
#           [ 0.0000, -0.0656, -0.0000]],
#
#          [[-0.6086, -0.0000, -0.7711],
#           [ 0.0000, -0.0000,  0.0000],
#           [-0.0000,  0.2712, -0.3572]],
#
#          [[-0.0000, -0.0000, -0.0065],
#           [ 0.0000, -0.3272, -0.1981],
#           [-0.0000,  0.0977,  0.0000]]]], grad_fn=<MulBackward0>)

# %%
math.sqrt(0)
# Out:
# 0.0

# %%
updated_tensor[0].std()
# Out:
# tensor(0.3611, grad_fn=<StdBackward0>)

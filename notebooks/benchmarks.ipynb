# %%
# %matplotlib inline
import torch
import torch.nn as nn
from torch.utils import benchmark
import pandas as pd
import matplotlib.pyplot as plt

from condensed_sparsity.models import LinearCondensed

# %%
import pickle
result_type = "gpu"
with open(f"../compare_{result_type}.pkl", "rb") as handle:
    compare = pickle.load(handle)
print(compare)
# Out:
# [----------- Linear ----------]
#                       |  Linear
# 1 threads: --------------------
#       1      x 65536  |    83.0
#       2      x 65536  |    58.7
#       4      x 65536  |    58.9
#       8      x 65536  |    59.0
#       16     x 65536  |    58.7
#       32     x 65536  |    58.9
#       64     x 65536  |    60.5
#       128    x 65536  |    86.7
#       256    x 65536  |   162.3
#       512    x 65536  |   330.7
#       1024   x 65536  |   638.5
#       2048   x 65536  |  1371.3
#
# Times are in microseconds (us).
#
# [------------------------------------------------------------------------- Linear Condensed -------------------------------------------------------------------------]
#                       |  Linear Condensed @ sparsity 0.5  |  Linear Condensed @ sparsity 0.9  |  Linear Condensed @ sparsity 0.95  |  Linear Condensed @ sparsity 0.99
# 1 threads: -----------------------------------------------------------------------------------------------------------------------------------------------------------
#       1      x 65536  |                723.4              |                254.2              |                192.7               |                137.5
#       2      x 65536  |                725.3              |                256.4              |                195.0               |                141.0
#       4      x 65536  |                728.5              |                257.5              |                194.6               |                140.2
#       8      x 65536  |                725.5              |                257.0              |                195.6               |                141.5
#       16     x 65536  |                726.3              |                258.3              |                195.5               |                140.4
#       32     x 65536  |                748.0              |                259.2              |                196.6               |                141.8
#       64     x 65536  |                931.8              |                259.4              |                196.9               |                142.4
#       128    x 65536  |               1327.1              |                333.1              |                207.3               |                143.2
#       256    x 65536  |               2119.0              |                525.3              |                315.9               |                198.3
#       512    x 65536  |               3696.0              |                904.5              |                534.2               |                357.4
#       1024   x 65536  |               6878.7              |               1672.3              |                976.5               |                672.4
#       2048   x 65536  |              13220.5              |               3199.5              |               1858.1               |               1305.2
#
# Times are in microseconds (us).

# %%
import re
import pandas as pd
import numpy as np
plt.style.use("../plt_plot_style.mplstyle")
data = {
    "sparsity": [],
    "batch_size": [],
    "num_features": [],
    "time": [],
    "std": []
}
for measurement in compare._results:
    desc = measurement.description
    sparsity = desc[-3:]
    if sparsity == "0.5":
        continue
    if desc == "Linear":
        data["sparsity"].append(0.0)
    else:
        data["sparsity"].append(float(desc[-3:]))
    batch, num_features = re.findall(r"[0-9]+", measurement.sub_label)
    data["batch_size"].append(int(batch))
    data["num_features"].append(int(num_features))
    data["time"].append(measurement.median*1e6)
    data["std"].append(np.std(measurement.times)*1e6)
df = pd.DataFrame(data)
df = df.sort_values(by="batch_size")
fig, ax = plt.subplots(figsize=(12,8))
for s in df["sparsity"].unique():
    df_slice = df.loc[df["sparsity"] == s]
    # df_slice = df_slice.groupby("batch_size").agg(mean_time=("time", "mean"), std_time=("time", "std")).reset_index()
    ax.plot(df_slice["batch_size"], df_slice["time"], label=s, marker="x")
    ax.fill_between(
        df_slice["batch_size"],
        df_slice["time"]+df_slice["std"],
        df_slice["time"]-df_slice["std"],
        alpha=0.2
    )
plt.legend()
plt.ylabel("Time (micro seconds)")
plt.xlabel("Batch Size")
plt.title(f"{result_type.upper()} Benchmark")
ax.set_xscale("log")
ax.set_yscale("log")
plt.show()
fig.savefig(f"{result_type}_benchmark.png", dpi=400, transparent=False)

# %%
compare._results[3]
# Out:
# <torch.utils.benchmark.utils.common.Measurement object at 0x7fca1e2a4d30>
# Linear Condensed: 1      x 65536
# Linear Condensed @ sparsity 0.95
# setup: from __main__ import lc_benchmark
#   Median: 130.67 us
#   IQR:    6.70 us (129.09 to 135.79)
#   15 measurements, 1000 runs per measurement, 48 threads

# %%
df
# Out:
#     sparsity  batch_size  num_features          time       std
# 0       0.00           1         65536     82.598999  0.016711
# 1       0.50           1         65536    725.206913  4.716119
# 2       0.90           1         65536    256.441737  0.308258
# 3       0.95           1         65536    194.979102  0.412356
# 4       0.99           1         65536    140.721080  0.284057
# 5       0.00           2         65536     57.736942  0.800053
# 6       0.50           2         65536    735.177411  2.053451
# 7       0.90           2         65536    259.567969  0.241634
# 8       0.95           2         65536    197.754107  0.364691
# 9       0.99           2         65536    144.122342  0.357124
# 14      0.99           4         65536    144.043296  0.502513
# 12      0.90           4         65536    259.872772  0.576793
# 13      0.95           4         65536    197.590299  0.356386
# 10      0.00           4         65536     58.187931  0.857187
# 11      0.50           4         65536    735.936660  3.043637
# 15      0.00           8         65536     57.550368  0.481913
# 16      0.50           8         65536    737.055934  2.284915
# 17      0.90           8         65536    259.923794  0.465807
# 18      0.95           8         65536    198.175364  0.362303
# 19      0.99           8         65536    144.842566  0.355285
# 20      0.00          16         65536     57.872700  1.882001
# 21      0.50          16         65536    736.308119  2.798206
# 22      0.90          16         65536    260.126703  0.252346
# 23      0.95          16         65536    198.027665  0.323017
# 24      0.99          16         65536    143.537325  0.384478
# 28      0.95          32         65536    198.266865  0.353059
# 27      0.90          32         65536    260.952200  0.309359
# 29      0.99          32         65536    145.107391  0.294673
# 25      0.00          32         65536     57.715827  1.299260
# 26      0.50          32         65536    751.822533  2.061766
# 30      0.00          64         65536     59.247368  1.024166
# 31      0.50          64         65536    937.416610  1.512060
# 32      0.90          64         65536    261.996906  0.255649
# 33      0.95          64         65536    200.009174  0.291687
# 34      0.99          64         65536    145.446731  0.234932
# 35      0.00         128         65536     86.625362  0.055332
# 36      0.50         128         65536   1333.988649  0.386673
# 37      0.90         128         65536    334.983442  0.230907
# 38      0.95         128         65536    208.662830  0.276273
# 39      0.99         128         65536    146.142485  0.282870
# 44      0.99         256         65536    197.200925  0.033957
# 42      0.90         256         65536    524.991391  0.198958
# 43      0.95         256         65536    315.921329  0.083561
# 40      0.00         256         65536    162.198944  0.021039
# 41      0.50         256         65536   2127.379614  0.437105
# 45      0.00         512         65536    330.648505  0.047953
# 46      0.50         512         65536   3709.186681  0.277983
# 47      0.90         512         65536    905.372270  0.400812
# 48      0.95         512         65536    538.040119  0.245751
# 49      0.99         512         65536    357.601201  0.061992
# 54      0.99        1024         65536    674.472063  0.045823
# 53      0.95        1024         65536    976.215646  0.017432
# 51      0.50        1024         65536   6878.490932  0.431410
# 50      0.00        1024         65536    637.941537  0.117975
# 52      0.90        1024         65536   1672.859397  0.023190
# 58      0.95        2048         65536   1860.834830  0.046368
# 55      0.00        2048         65536   1372.391991  0.124100
# 56      0.50        2048         65536  13214.848517  0.084202
# 57      0.90        2048         65536   3197.811274  0.061719
# 59      0.99        2048         65536   1310.081780  0.040651

# %%
df.loc[(df["sparsity"]=="Dense") & (df["batch_size"] == 1024)]["time"]
# Out:
# 4      82.144048
# 19     59.696882
# 164    59.185702
# 69     58.368453
# 74     59.095949
# 79     59.595541
# 249    59.705100
# Name: time, dtype: float64

# %%
df["batch_size"].value_counts()
# Out:
# 1024    35
# 16      30
# 1       25
# 4       25
# 8       25
# 32      25
# 256     25
# 2       20
# 128     20
# 64      10
# 512     10
# Name: batch_size, dtype: int64

# %%
compare._results[0].
# Out:
# {'number_per_run': 1000,
#  'raw_times': [0.16171245370060205,
#   0.16129795461893082,
#   0.16009330190718174,
#   0.16024847328662872,
#   0.1602011201903224,
#   0.1599385947920382,
#   0.16024579806253314],
#  'task_spec': <torch.utils.benchmark.utils.common.TaskSpec at 0x7fbc8829aa00>,
#  'metadata': None,
#  '_sorted_times': (0.0001599385947920382,
#   0.00016009330190718175,
#   0.0001602011201903224,
#   0.00016024579806253315,
#   0.00016024847328662873,
#   0.0001612979546189308,
#   0.00016171245370060204),
#  '_warnings': (),
#  '_median': 0.00016024579806253315,
#  '_mean': 0.00016053395665117674,
#  '_p25': 0.00016014721104875207,
#  '_p75': 0.00016077321395277977}

# %%
print(compare)
# Out:
# [--------------------------------------------------------------------------------- Linear Condensed --------------------------------------------------------------------------------]
#                                      |  Linear Condensed @ sparsity 0.5  |  Linear Condensed @ sparsity 0.9  |  Linear Condensed @ sparsity 0.95  |  Linear Condensed @ sparsity 0.99
# 1 threads: --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#       256    x 2582                  |               160.2               |               134.3               |               131.7                |               129.9
#       2      x 85   (discontiguous)  |               130.4               |               128.2               |               128.5                |                91.7
#       1      x 8589                  |               215.5               |               150.1               |               137.0                |               129.7
#       2      x 161                   |               131.6               |               130.5               |               129.4                |               127.3
#       8      x 278                   |               134.4               |               130.7               |               129.9                |               127.8
#       4      x 407  (discontiguous)  |               135.6               |               130.8               |               130.6                |               128.1
#       8      x 9187 (discontiguous)  |               223.6               |               153.0               |               140.5                |               132.5
#       2      x 88   (discontiguous)  |               131.2               |               128.9               |               128.6                |                92.1
#       1      x 205                   |               129.4               |               126.3               |               126.8                |               125.6
#       128    x 153                   |               131.4               |               130.1               |               129.6                |               129.2
#       64     x 548                   |               135.6               |               130.8               |               130.8                |               129.5
#       1      x 4508                  |               176.3               |               136.3               |               132.4                |               128.2
#       256    x 2521                  |               160.3               |               135.0               |               132.4                |               130.5
#       16     x 8218 (discontiguous)  |               213.4               |               151.8               |               138.0                |               133.4
#       128    x 388                   |               134.5               |               131.2               |               131.5                |               129.9
#       2      x 3681 (discontiguous)  |               171.8               |               137.4               |               134.0                |               131.7
#       2      x 65   (discontiguous)  |               130.5               |               130.0               |               128.8                |                87.9
#       128    x 1366 (discontiguous)  |               139.1               |               128.8               |               127.4                |               125.5
#       128    x 619                   |               132.2               |               126.1               |               124.7                |               125.4
#       64     x 1849                  |               147.6               |               128.8               |               127.6                |               125.3
#       32     x 442  (discontiguous)  |               130.3               |               127.0               |               125.9                |               125.1
#       32     x 3144                  |               161.7               |               131.7               |               128.8                |               125.9
#       8      x 72                    |               125.7               |               125.0               |               123.7                |                87.8
#       32     x 313  (discontiguous)  |               129.4               |               125.9               |               125.8                |               124.7
#       32     x 978  (discontiguous)  |               136.0               |               127.5               |               127.8                |               125.7
#       4      x 144  (discontiguous)  |               126.3               |               124.8               |               125.0                |               123.4
#       1      x 642                   |               130.1               |               124.9               |               123.1                |               121.3
#       128    x 329                   |               128.2               |               125.2               |               124.7                |               124.3
#       256    x 253                   |               127.4               |               126.0               |               125.8                |               124.7
#       8      x 298                   |               130.1               |               125.1               |               125.5                |               122.6
#       16     x 2114                  |               151.8               |               129.4               |               128.3                |               125.5
#       2      x 193                   |               127.4               |               124.1               |               124.8                |               123.6
#       1      x 230                   |               125.0               |               122.8               |               122.2                |               120.4
#       4      x 269  (discontiguous)  |               127.6               |               126.0               |               124.9                |               123.7
#       4      x 6291                  |               189.7               |               137.6               |               131.3                |               125.3
#       16     x 9300 (discontiguous)  |               218.2               |               148.2               |               134.6                |               127.2
#       8      x 217                   |               127.6               |               125.7               |               125.1                |               123.6
#       256    x 479  (discontiguous)  |               131.4               |               126.0               |               127.2                |               126.6
#       4      x 164                   |               128.3               |               125.0               |               124.7                |               123.8
#       64     x 69                    |               126.1               |               125.2               |               125.7                |                88.6
#       32     x 154                   |               126.7               |               125.7               |               125.6                |               124.1
#       256    x 128                   |               126.6               |               125.9               |               125.4                |               124.0
#       256    x 5381 (discontiguous)  |               297.3               |               137.0               |               130.1                |               125.4
#       16     x 238  (discontiguous)  |               127.9               |               126.0               |               125.3                |               124.3
#       256    x 1567                  |               142.7               |               128.7               |               126.2                |               126.4
#       64     x 5946 (discontiguous)  |               188.1               |               137.7               |               131.8                |               126.4
#       256    x 3381                  |               163.7               |               131.9               |               128.7                |               125.7
#       8      x 7390                  |               201.0               |               140.8               |               134.2                |               126.9
#       4      x 743  (discontiguous)  |               132.8               |               125.5               |               126.3                |               124.8
#       1      x 775                   |               131.9               |               124.1               |               123.3                |               120.5
#
# Times are in microseconds (us).
#
# [------------------ Linear ------------------]
#                                      |  Linear
# 1 threads: -----------------------------------
#       256    x 2582                  |   83.6
#       2      x 85   (discontiguous)  |   50.1
#       1      x 8589                  |   59.2
#       2      x 161                   |   51.0
#       8      x 278                   |   50.9
#       4      x 407  (discontiguous)  |   59.1
#       8      x 9187 (discontiguous)  |   58.7
#       2      x 88   (discontiguous)  |   50.1
#       1      x 205                   |   50.7
#       128    x 153                   |   50.5
#       64     x 548                   |   59.5
#       1      x 4508                  |   59.2
#       256    x 2521                  |   59.2
#       16     x 8218 (discontiguous)  |   59.2
#       128    x 388                   |   59.6
#       2      x 3681 (discontiguous)  |   59.7
#       2      x 65   (discontiguous)  |   48.0
#       128    x 1366 (discontiguous)  |   57.6
#       128    x 619                   |   56.8
#       64     x 1849                  |   56.8
#       32     x 442  (discontiguous)  |   57.3
#       32     x 3144                  |   56.9
#       8      x 72                    |   47.4
#       32     x 313  (discontiguous)  |   57.2
#       32     x 978  (discontiguous)  |   57.1
#       4      x 144  (discontiguous)  |   47.8
#       1      x 642                   |   56.3
#       128    x 329                   |   56.9
#       256    x 253                   |   56.5
#       8      x 298                   |   48.7
#       16     x 2114                  |   56.7
#       2      x 193                   |   49.2
#       1      x 230                   |   48.3
#       4      x 269  (discontiguous)  |   56.6
#       4      x 6291                  |   56.5
#       16     x 9300 (discontiguous)  |   56.6
#       8      x 217                   |   49.0
#       256    x 479  (discontiguous)  |   58.1
#       4      x 164                   |   48.7
#       64     x 69                    |   48.6
#       32     x 154                   |   48.6
#       256    x 128                   |   48.3
#       256    x 5381 (discontiguous)  |   57.7
#       16     x 238  (discontiguous)  |   56.6
#       256    x 1567                  |   57.0
#       64     x 5946 (discontiguous)  |   57.3
#       256    x 3381                  |   57.0
#       8      x 7390                  |   56.7
#       4      x 743  (discontiguous)  |   56.0
#       1      x 775                   |   49.2
#
# Times are in microseconds (us).

# %%
df_slice["time"]
# Out:
# 43     125.581254
# 133    121.344458
# 248    120.485745
# 58     128.155211
# 163    120.363428
# 13     129.685441
# 78     131.737106
# 158    123.574821
# 8       91.730111
# 83      87.901600
# 18     127.311997
# 38      92.142595
# 168    123.746805
# 193    123.835034
# 128    123.356488
# 28     128.143633
# 243    124.839980
# 173    125.319584
# 113     87.753279
# 148    122.615424
# 23     127.784553
# 238    126.868860
# 183    123.556189
# 33     132.517780
# 153    125.470408
# 218    124.256704
# 178    127.197951
# 68     133.413050
# 203    124.092071
# 103    125.065685
# 108    125.888155
# 118    124.684060
# 123    125.746259
# 198     88.613903
# 98     125.294512
# 53     129.545197
# 228    126.374462
# 73     129.861717
# 138    124.285895
# 93     125.394706
# 88     125.481698
# 48     129.170376
# 223    126.410716
# 3      129.924004
# 233    125.708434
# 143    124.735837
# 188    126.583376
# 208    124.007753
# 213    125.391100
# 63     130.498093
# Name: time, dtype: float64

# %%
df_slice["std"]
# Out:
# 43     1285.511933
# 133     784.327621
# 248    1355.681002
# 58     1013.180325
# 163     404.625006
# 13      370.533930
# 78     4043.948875
# 158    1163.177724
# 8      3762.955079
# 83     5974.215354
# 18      368.062653
# 38     1267.570071
# 168     636.280135
# 193    1151.662413
# 128     962.014436
# 28     1141.559017
# 243     261.697099
# 173    1066.159259
# 113    1408.412354
# 148     312.935283
# 23      248.021783
# 238     406.244946
# 183     419.612925
# 33     1350.155207
# 153     929.381873
# 218     433.069983
# 178     348.271148
# 68      403.155041
# 203     510.653930
# 103     873.101047
# 108     275.391877
# 118     437.017708
# 123     128.276015
# 198    3104.252042
# 98     1082.814891
# 53      307.604050
# 228    1239.075275
# 73      384.923156
# 138     392.923542
# 93      579.522034
# 88      459.873980
# 48      504.069956
# 223     109.277376
# 3       556.904481
# 233     721.369713
# 143     382.393102
# 188    2149.580412
# 208     640.273906
# 213    2396.318858
# 63      940.665198
# Name: std, dtype: float64

# %%
compare._results[0].description
# Out:
# 'Linear Condensed @ sparsity 0.9'

# %%
for tensors, tensor_params, params in fuzzer.take(1):
    break

# %%
tensors["x"].shape
# Out:
# torch.Size([256, 2582])

# %%
torch.device("cuda:0")
# Out:
# device(type='cuda', index=0)

# %%
lc_params=dict(
    in_features= tensors["x"].shape[1],
    out_features=10,
    bias=True,
    input_len=tensors["x"].shape[1],
    fan_out_const=True,
    device=torch.device("cuda:0"),
    dtype=torch.float32

)
lc = LinearCondensed(**lc_params)
lc
# Out:
# LinearCondensed(in_features=2582, out_features=10, bias=True)

# %%
lc._parameters["weight"]
# Out:
# Parameter containing:
# tensor([[-0.0120,  0.0014, -0.0042,  ..., -0.0052,  0.0077, -0.0084],
#         [ 0.0131,  0.0196,  0.0184,  ..., -0.0040,  0.0142,  0.0021],
#         [ 0.0051, -0.0187,  0.0127,  ..., -0.0091, -0.0020, -0.0009],
#         ...,
#         [ 0.0124,  0.0086, -0.0120,  ..., -0.0111,  0.0088, -0.0119],
#         [ 0.0175, -0.0137, -0.0091,  ...,  0.0066, -0.0138, -0.0105],
#         [-0.0052,  0.0181,  0.0081,  ...,  0.0069, -0.0090,  0.0097]],
#        device='cuda:0', requires_grad=True)

# %%
tensor_params
# Out:
# {'x': {'numel': 186325,
#   'order': array([0, 1]),
#   'steps': (1, 1),
#   'is_contiguous': True,
#   'dtype': 'torch.float32'}}

# %%
params
# Out:
# {'k0': 725, 'k1': 257}

# %%
tensors["x"].shape
# Out:
# torch.Size([725, 257])

# %%
results = []
for tensors, tensor_params, params in fuzzer.take(10):
    # description is the column label
    sub_label=f"{params['k0']:<6} x {params['k1']:<4} {'' if tensor_params['x']['is_contiguous'] else '(discontiguous)'}"
    results.append(benchmark.Timer(
        stmt='batched_dot_mul_sum(x, x)',
        setup='from __main__ import batched_dot_mul_sum',
        globals=tensors,
        label='Batched dot',
        sub_label=sub_label,
        description='mul/sum',
    ).blocked_autorange(min_run_time=1))
    results.append(benchmark.Timer(
        stmt='batched_dot_bmm(x, x)',
        setup='from __main__ import batched_dot_bmm',
        globals=tensors,
        label='Batched dot',
        sub_label=sub_label,
        description='bmm',
    ).blocked_autorange(min_run_time=1))

compare = benchmark.Compare(results)
compare.trim_significant_figures()
compare.print()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_1412/910901689.py in <module>
#       3     # description is the column label
#       4     sub_label=f"{params['k0']:<6} x {params['k1']:<4} {'' if tensor_params['x']['is_contiguous'] else '(discontiguous)'}"
# ----> 5     results.append(benchmark.Timer(
#       6         stmt='batched_dot_mul_sum(x, x)',
#       7         setup='from __main__ import batched_dot_mul_sum',
#
# /opt/conda/lib/python3.8/site-packages/torch/utils/benchmark/utils/timer.py in blocked_autorange(self, callback, min_run_time)
#     392             (mean, median, etc.)
#     393         """
# --> 394         number = self._estimate_block_size(min_run_time)
#     395
#     396         def time_hook() -> float:
#
# /opt/conda/lib/python3.8/site-packages/torch/utils/benchmark/utils/timer.py in _estimate_block_size(self, min_run_time)
#     306             # Estimate the block size needed for measurement to be negligible
#     307             # compared to the inner loop. This also serves as a warmup.
# --> 308             overhead = torch.tensor([self._timeit(0) for _ in range(5)]).median().item()
#     309             number = 1
#     310             while True:
#
# /opt/conda/lib/python3.8/site-packages/torch/utils/benchmark/utils/timer.py in <listcomp>(.0)
#     306             # Estimate the block size needed for measurement to be negligible
#     307             # compared to the inner loop. This also serves as a warmup.
# --> 308             overhead = torch.tensor([self._timeit(0) for _ in range(5)]).median().item()
#     309             number = 1
#     310             while True:
#
# /opt/conda/lib/python3.8/site-packages/torch/utils/benchmark/utils/timer.py in _timeit(self, number)
#     254         # Even calling a timer in C++ takes ~50 ns, so no real operation should
#     255         # take less than 1 ns. (And this prevents divide by zero errors.)
# --> 256         return max(self._timer.timeit(number), 1e-9)
#     257
#     258     def timeit(self, number: int = 1000000) -> common.Measurement:
#
# /opt/conda/lib/python3.8/timeit.py in timeit(self, number)
#     175         gc.disable()
#     176         try:
# --> 177             timing = self.inner(it, self.timer)
#     178         finally:
#     179             if gcold:
#
# <timeit-src> in inner(_it, _timer)
#
# ImportError: cannot import name 'batched_dot_mul_sum' from '__main__' (unknown location)
